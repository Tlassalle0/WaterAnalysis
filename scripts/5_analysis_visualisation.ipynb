# %%
import numpy as np #numpy is a library that have many mathematical operations with arrays 
import pandas as pd #panda is a library that help the use of DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('C:/Users/MV_pe/OneDrive/Documents/Ynov/B3_(2025-2026)/Analyse et Exploration de Données/Projet/WaterAnalysis/data/2-interim/Daily_Water_Intake_Cleaned.csv')
df.describe()
# Out:
#                 Age   Weight (kg)  Daily Water Intake (liters)
# count  29662.000000  29662.000000                 29662.000000
# mean      43.408199     77.065471                     2.864480
# std       14.990058     18.677993                     0.829543
# min       18.000000     45.000000                     1.500000
# 25%       30.000000     61.000000                     2.230000
# 50%       43.000000     77.000000                     2.840000
# 75%       56.000000     93.000000                     3.450000
# max       69.000000    109.000000                     5.430000

# %%
fig, axes = plt.subplots(1,2, figsize=(15, 10))


# Données originales avec manquantes
axes[0].boxplot([df['Age'], df['Weight (kg)']], 
                  labels=['Age', 'Weight'])
axes[0].set_title('Box')
axes[0].set_ylabel('Valeurs')

axes[1].boxplot([df['Daily Water Intake (liters)']],labels=['Daily Water Intake (liters)'])
axes[1].set_title('Boxplot Daily Water Intake (liters)')
axes[1].set_ylabel('Valeurs')
# Out:
# C:\Users\MV_pe\AppData\Local\Temp\ipykernel_11556\3059546301.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[0].boxplot([df['Age'], df['Weight (kg)']],
# C:\Users\MV_pe\AppData\Local\Temp\ipykernel_11556\3059546301.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot([df['Daily Water Intake (liters)']],labels=['Daily Water Intake (liters)'])
# Text(0, 0.5, 'Valeurs')

# %%
fig, axes = plt.subplots(1,2, figsize=(15, 10))
palette = {'Male': 'skyblue', 'Female': 'lightpink'}
bins = [44.99, 61, 77, 93, 109.01]
labels = ['44.99-61 kg', '62-77 kg', '78-93 kg', '94-109.01 kg']
df_grpWeight = df.copy()
df_grpWeight['Weight Group'] = pd.cut(df_grpWeight['Weight (kg)'], bins=bins, labels=labels,include_lowest=True)
palette_weight = {
    '44.99-61 kg': 'lightgreen',
    '62-77 kg': 'orange',
    '78-93 kg': 'lightcoral',
    '94-109.01 kg': 'purple'
}




sns.boxplot(data=df_grpWeight, x="Gender", y="Daily Water Intake (liters)", palette=palette, ax=axes[0])
axes[0].set_title('Boxplot Daily Water Intake (liters)')
axes[0].set_ylabel('Valeurs')

sns.boxplot(data=df_grpWeight, x="Weight Group", y="Daily Water Intake (liters)", palette=palette_weight, ax=axes[1])
axes[1].set_title('Boxplot Daily Water Intake (liters)')
axes[1].set_ylabel('Valeurs')
# Out:
# C:\Users\MV_pe\AppData\Local\Temp\ipykernel_11556\399544217.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_grpWeight, x="Gender", y="Daily Water Intake (liters)", palette=palette, ax=axes[0])
# C:\Users\MV_pe\AppData\Local\Temp\ipykernel_11556\399544217.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_grpWeight, x="Weight Group", y="Daily Water Intake (liters)", palette=palette_weight, ax=axes[1])
# Text(0, 0.5, 'Valeurs')

# %%
fig, ax = plt.subplots(figsize=(15, 10))
palette = {'Male': 'skyblue', 'Female': 'lightpink'}
bins = [44.99, 61, 77, 93, 109.01]



sns.boxplot(data=df, x="Gender", y="Daily Water Intake", palette=palette, ax=ax)
ax.set_title('Boxplot Daily Water Intake (liters)')
ax.set_ylabel('Valeurs')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 7
#       2 palette = {'Male': 'skyblue', 'Female': 'lightpink'}
#       3 bins = [44.99, 61, 77, 93, 109.01]
# ----> 7 sns.boxplot(data=df, x="Gender", y="Daily Water Intake", palette=palette, ax=ax)
#       8 ax.set_title('Boxplot Daily Water Intake (liters)')
#       9 ax.set_ylabel('Valeurs')
#
# File c:\Users\MV_pe\anaconda3\envs\PythonAnalyseDonnees\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
# ...

# %%
df['Physical Activity Level'] = pd.Categorical(
    df['Physical Activity Level'],
    categories=['Low', 'Moderate', 'High'],
    ordered=True
)

activity_water = (
    df.groupby("Physical Activity Level")["Daily Water Intake (liters)"]
      .mean()
)
plt.figure(figsize=(8, 6))

plt.bar(
    activity_water.index,
    activity_water.values,
    color=['skyblue', 'lightpink', 'red']
)

plt.title("Average Daily Water Intake by Physical Activity Level")
plt.xlabel("Physical Activity Level")
plt.ylabel("Daily Water Intake (liters)")
plt.show()
# Out:
# C:\Users\MV_pe\AppData\Local\Temp\ipykernel_7072\3604390823.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("Physical Activity Level")["Daily Water Intake"]

# %%
df_encoded = df.copy()
df_encoded = df_encoded.drop(columns=['Gender'])
df_encoded['Physical Activity Level'] = df_encoded['Physical Activity Level'].map({'Low':0,'Moderate':1,'High':2})
df_encoded['Weather'] = df_encoded['Weather'].map({'Cold':0,'Normal':1,'Hot':2})
df_encoded['Hydration Level'] = df_encoded['Hydration Level'].map({'Poor':0,'Good':1})

matrix = df_encoded.corr()

sns.heatmap(matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.show()

# %%
sns.histplot(data=df, x="Daily Water Intake (liters)", bins=20, kde=True, color='skyblue')
# Out:
# <Axes: xlabel='Daily Water Intake (liters)', ylabel='Count'>

# %%
df_grpWeight['Weather'] = pd.Categorical(
    df['Weather'],
    categories=['Cold', 'Normal', 'Hot'],
    ordered=True
)

sns.boxplot(data=df_grpWeight, x="Weather", y="Daily Water Intake (liters)", hue="Weight Group", palette=palette_weight)
# Out:
# <Axes: xlabel='Weather', ylabel='Daily Water Intake (liters)'>
