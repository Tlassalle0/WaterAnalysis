# %%
import pandas as pd
import matplotlib.pyplot as plt

path = "../data/1-raw/Daily_Water_Intake.csv"
df = pd.read_csv(path)

# %%
# Plot Age
plt.figure()
plt.hist(df["Age"].dropna())
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Distribution of Age")
plt.show()

# %%
# Plot Weight
plt.figure()
plt.hist(df["Weight"].dropna())
plt.xlabel("Weight")
plt.ylabel("Count")
plt.title("Distribution of Weight")
plt.show()

# %%
# Plot Gender
plt.figure()
plt.hist(df["Gender"].dropna())
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Distribution of Gender")
plt.show()

# %%
df['Weather'] = pd.Categorical(
    df['Weather'],
    categories=['Cold', 'Normal', 'Hot'],
    ordered=True
)

# Count occurrences
counts = (
    df.groupby(["Weather", "Hydration Level"])
      .size()
      .unstack(fill_value=0)
)

# Plot stacked bars
counts.plot(
    kind="bar",
    stacked=True,
    color=["blue", "red"]
)

plt.xlabel("Weather")
plt.ylabel("Count")
plt.title("Weather vs Hydration Level")
plt.legend(title="Hydration Level")
plt.show()
# Out:
# C:\Users\MV_pe\AppData\Local\Temp\ipykernel_8600\2617190133.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["Weather", "Hydration Level"])

# %%
# Plot Weight

plt.figure()
plt.hist(df["Physical Activity Level"].dropna())
plt.xlabel("Physical Activity Level")
plt.ylabel("Count")
plt.title("Distribution of Physical Activity Level")
plt.show()

# %%
# Plot Hydration Level
plt.figure()
plt.hist(df["Hydration Level"].dropna())
plt.xlabel("Hydration Level")
plt.ylabel("Count")
plt.title("Distribution of Hydration Level")
plt.show()
